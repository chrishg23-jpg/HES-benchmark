# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/QFT2001c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# QFT2001c — Low-damping, no-noise localized bundle (3D, 64³, N=100)

import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 1. Core parameters
# -----------------------------
L = 64
N_int = 100

lambda_c = 0.02      # same coupling
gamma = 0.04         # lower damping
noise_amp = 0.0      # no stochastic noise
n_steps = 1000
save_every = 10

rng = np.random.default_rng(2001)

shape_field = (L, L, L, N_int)

def laplacian_3d_periodic(field):
    xp = np.roll(field, +1, axis=0)
    xm = np.roll(field, -1, axis=0)
    yp = np.roll(field, +1, axis=1)
    ym = np.roll(field, -1, axis=1)
    zp = np.roll(field, +1, axis=2)
    zm = np.roll(field, -1, axis=2)
    lap = (xp + xm + yp + ym + zp + zm - 6.0 * field)
    return lap

# -----------------------------
# 2. Initialize fields with a localized Gaussian bump
# -----------------------------
x = 1e-3 * rng.standard_normal(size=shape_field).astype(np.float64)
v = 1e-3 * rng.standard_normal(size=shape_field).astype(np.float64)

cx, cy, cz = L // 2, L // 2, L // 2
sigma = 4.0
amp_bump = 0.05

X = np.arange(L)
Y = np.arange(L)
Z = np.arange(L)
XX, YY, ZZ = np.meshgrid(X, Y, Z, indexing='ij')

dx = XX - cx
dy = YY - cy
dz = ZZ - cz
r2 = dx**2 + dy**2 + dz**2

gauss = np.exp(-r2 / (2.0 * sigma**2))

x[..., 0] += amp_bump * gauss

# -----------------------------
# 3. Diagnostics storage
# -----------------------------
times = []
vacuum_var = []
vacuum_energy = []
mode_spectra = []
max_local_amp = []
patch_amp = []

patch_radius = 3

def compute_diagnostics(t, x, v):
    var_x = np.var(x)

    ke = np.mean(v**2)
    lap_x = laplacian_3d_periodic(x)
    ge = np.mean(lap_x**2)
    vac_E = ke + ge

    amp = np.sqrt(np.sum(x**2, axis=-1))
    max_amp = np.max(amp)

    r = patch_radius
    xs = slice(cx - r, cx + r + 1)
    ys = slice(cy - r, cy + r + 1)
    zs = slice(cz - r, cz + r + 1)
    local_patch = amp[xs, ys, zs]
    local_mean = np.mean(local_patch)

    comp = x[..., 0]
    fft3 = np.fft.fftn(comp)
    power3 = np.abs(fft3)**2

    kx = np.fft.fftfreq(L)
    ky = np.fft.fftfreq(L)
    kz = np.fft.fftfreq(L)
    KX, KY, KZ = np.meshgrid(kx, ky, kz, indexing='ij')
    kr = np.sqrt(KX**2 + KY**2 + KZ**2)

    n_bins = L // 2
    bins = np.linspace(0, np.max(kr), n_bins + 1)
    radial_power = np.zeros(n_bins, dtype=np.float64)
    counts = np.zeros(n_bins, dtype=np.int64)

    kr_flat = kr.ravel()
    p_flat = power3.ravel()
    inds = np.digitize(kr_flat, bins) - 1
    valid = (inds >= 0) & (inds < n_bins)
    for i, p in zip(inds[valid], p_flat[valid]):
        radial_power[i] += p
        counts[i] += 1
    counts[counts == 0] = 1
    radial_power /= counts

    return var_x, vac_E, radial_power, max_amp, local_mean

# -----------------------------
# 4. Main evolution
# -----------------------------
print("Starting QFT2001c 3D evolution (low-damping, no-noise bump): L=64, N_int=100, steps=", n_steps)

for t in range(n_steps):
    lap_x = laplacian_3d_periodic(x)
    eta = noise_amp * rng.standard_normal(size=shape_field).astype(np.float64)

    v = v + lambda_c * lap_x - gamma * v + eta
    x = x + v

    if t % save_every == 0 or t == n_steps - 1:
        var_x, vac_E, radial_power, max_amp, local_mean = compute_diagnostics(t, x, v)
        times.append(t)
        vacuum_var.append(var_x)
        vacuum_energy.append(vac_E)
        mode_spectra.append(radial_power)
        max_local_amp.append(max_amp)
        patch_amp.append(local_mean)
        print(f"t={t:4d}  var_x={var_x:.3e}  vac_E={vac_E:.3e}  "
              f"max_amp={max_amp:.3e}  patch_amp={local_mean:.3e}")

print("Evolution complete.")

times = np.array(times)
vacuum_var = np.array(vacuum_var)
vacuum_energy = np.array(vacuum_energy)
mode_spectra = np.array(mode_spectra)
max_local_amp = np.array(max_local_amp)
patch_amp = np.array(patch_amp)

# -----------------------------
# 5. Plots
# -----------------------------
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

axs[0, 0].plot(times, vacuum_var, '-o', ms=3)
axs[0, 0].set_title("Vacuum variance of x")
axs[0, 0].set_xlabel("time step")
axs[0, 0].set_ylabel("Var[x]")

axs[0, 1].plot(times, vacuum_energy, '-o', ms=3, color='orange')
axs[0, 1].set_title("Vacuum energy proxy (KE + gradE)")
axs[0, 1].set_xlabel("time step")
axs[0, 1].set_ylabel("Energy (arb. units)")

axs[1, 0].plot(times, max_local_amp, '-o', ms=3, color='green', label='global max |x|')
axs[1, 0].plot(times, patch_amp, '-o', ms=3, color='purple', label='local patch |x|')
axs[1, 0].set_title("Bundle indicator: global vs local")
axs[1, 0].set_xlabel("time step")
axs[1, 0].set_ylabel("amplitude")
axs[1, 0].legend()

if mode_spectra.shape[0] > 0:
    final_spec = mode_spectra[-1]
    axs[1, 1].plot(final_spec, '-o', ms=3, color='red')
    axs[1, 1].set_title("Radial mode spectrum (final snapshot)")
    axs[1, 1].set_xlabel("radial k-bin")
    axs[1, 1].set_ylabel("Power")

plt.tight_layout()
plt.show()

# -----------------------------
# 6. Summary
# -----------------------------
print("\n--- QFT2001c qualitative checks ---")
print("Final vacuum variance:", vacuum_var[-1])
print("Final vacuum energy proxy:", vacuum_energy[-1])
print("Final global max amplitude:", max_local_amp[-1])
print("Final local patch amplitude:", patch_amp[-1])
print("Mode spectra samples:", mode_spectra.shape[0], "snapshots")
# Out:
# Starting QFT2001c 3D evolution (low-damping, no-noise bump): L=64, N_int=100, steps= 1000
# t=   0  var_x=1.732e-06  vac_E=6.975e-05  max_amp=5.211e-02  patch_amp=3.723e-02
# t=  10  var_x=4.028e-06  vac_E=1.239e-04  max_amp=4.551e-02  patch_amp=3.511e-02
# t=  20  var_x=2.823e-06  vac_E=7.123e-05  max_amp=3.048e-02  patch_amp=2.526e-02
# t=  30  var_x=1.880e-06  vac_E=4.689e-05  max_amp=1.979e-02  patch_amp=1.654e-02
# t=  40  var_x=1.270e-06  vac_E=3.092e-05  max_amp=1.591e-02  patch_amp=1.169e-02
# t=  50  var_x=8.706e-07  vac_E=2.139e-05  max_amp=1.306e-02  patch_amp=9.375e-03
# t=  60  var_x=5.857e-07  vac_E=1.403e-05  max_amp=1.038e-02  patch_amp=7.702e-03
# t=  70  var_x=3.951e-07  vac_E=9.206e-06  max_amp=8.532e-03  patch_amp=6.293e-03
# t=  80  var_x=2.700e-07  vac_E=6.260e-06  max_amp=7.098e-03  patch_amp=5.263e-03
# t=  90  var_x=1.838e-07  vac_E=4.122e-06  max_amp=5.704e-03  patch_amp=4.486e-03
# t= 100  var_x=1.258e-07  vac_E=2.728e-06  max_amp=4.891e-03  patch_amp=3.786e-03
# t= 110  var_x=8.723e-08  vac_E=1.817e-06  max_amp=4.036e-03  patch_amp=3.167e-03
# t= 120  var_x=6.121e-08  vac_E=1.211e-06  max_amp=3.366e-03  patch_amp=2.689e-03
# t= 130  var_x=4.350e-08  vac_E=8.030e-07  max_amp=2.846e-03  patch_amp=2.313e-03
# t= 140  var_x=3.147e-08  vac_E=5.311e-07  max_amp=2.514e-03  patch_amp=2.046e-03
# t= 150  var_x=2.330e-08  vac_E=3.564e-07  max_amp=2.138e-03  patch_amp=1.837e-03
# t= 160  var_x=1.760e-08  vac_E=2.362e-07  max_amp=1.929e-03  patch_amp=1.644e-03
# t= 170  var_x=1.364e-08  vac_E=1.566e-07  max_amp=1.703e-03  patch_amp=1.474e-03
# t= 180  var_x=1.087e-08  vac_E=1.046e-07  max_amp=1.531e-03  patch_amp=1.326e-03
# t= 190  var_x=8.874e-09  vac_E=6.947e-08  max_amp=1.359e-03  patch_amp=1.207e-03
# t= 200  var_x=7.425e-09  vac_E=4.614e-08  max_amp=1.235e-03  patch_amp=1.112e-03
# t= 210  var_x=6.360e-09  vac_E=3.063e-08  max_amp=1.143e-03  patch_amp=1.039e-03
# t= 220  var_x=5.566e-09  vac_E=2.043e-08  max_amp=1.069e-03  patch_amp=9.789e-04
# t= 230  var_x=4.974e-09  vac_E=1.356e-08  max_amp=9.977e-04  patch_amp=9.246e-04
# t= 240  var_x=4.526e-09  vac_E=8.992e-09  max_amp=9.295e-04  patch_amp=8.790e-04
# t= 250  var_x=4.170e-09  vac_E=5.999e-09  max_amp=8.808e-04  patch_amp=8.388e-04
# t= 260  var_x=3.888e-09  vac_E=3.984e-09  max_amp=8.353e-04  patch_amp=8.051e-04
# t= 270  var_x=3.659e-09  vac_E=2.646e-09  max_amp=8.033e-04  patch_amp=7.737e-04
# t= 280  var_x=3.470e-09  vac_E=1.761e-09  max_amp=7.707e-04  patch_amp=7.448e-04
# t= 290  var_x=3.312e-09  vac_E=1.171e-09  max_amp=7.409e-04  patch_amp=7.195e-04
# t= 300  var_x=3.178e-09  vac_E=7.794e-10  max_amp=7.149e-04  patch_amp=6.961e-04
# t= 310  var_x=3.063e-09  vac_E=5.168e-10  max_amp=6.929e-04  patch_amp=6.759e-04
# t= 320  var_x=2.963e-09  vac_E=3.445e-10  max_amp=6.709e-04  patch_amp=6.575e-04
# t= 330  var_x=2.877e-09  vac_E=2.290e-10  max_amp=6.508e-04  patch_amp=6.411e-04
# t= 340  var_x=2.802e-09  vac_E=1.519e-10  max_amp=6.344e-04  patch_amp=6.260e-04
# t= 350  var_x=2.736e-09  vac_E=1.012e-10  max_amp=6.188e-04  patch_amp=6.124e-04
# t= 360  var_x=2.678e-09  vac_E=6.722e-11  max_amp=6.063e-04  patch_amp=6.005e-04
# t= 370  var_x=2.626e-09  vac_E=4.476e-11  max_amp=5.959e-04  patch_amp=5.896e-04
# t= 380  var_x=2.581e-09  vac_E=2.973e-11  max_amp=5.848e-04  patch_amp=5.799e-04
# t= 390  var_x=2.540e-09  vac_E=1.977e-11  max_amp=5.755e-04  patch_amp=5.710e-04
# t= 400  var_x=2.504e-09  vac_E=1.317e-11  max_amp=5.674e-04  patch_amp=5.631e-04
# t= 410  var_x=2.472e-09  vac_E=8.768e-12  max_amp=5.599e-04  patch_amp=5.560e-04
# t= 420  var_x=2.444e-09  vac_E=5.856e-12  max_amp=5.536e-04  patch_amp=5.497e-04
# t= 430  var_x=2.418e-09  vac_E=3.888e-12  max_amp=5.468e-04  patch_amp=5.438e-04
# t= 440  var_x=2.395e-09  vac_E=2.585e-12  max_amp=5.411e-04  patch_amp=5.384e-04
# t= 450  var_x=2.375e-09  vac_E=1.723e-12  max_amp=5.357e-04  patch_amp=5.333e-04
# t= 460  var_x=2.357e-09  vac_E=1.150e-12  max_amp=5.312e-04  patch_amp=5.286e-04
# t= 470  var_x=2.341e-09  vac_E=7.685e-13  max_amp=5.263e-04  patch_amp=5.243e-04
# t= 480  var_x=2.326e-09  vac_E=5.144e-13  max_amp=5.223e-04  patch_amp=5.204e-04
# t= 490  var_x=2.314e-09  vac_E=3.461e-13  max_amp=5.187e-04  patch_amp=5.168e-04
# t= 500  var_x=2.302e-09  vac_E=2.336e-13  max_amp=5.152e-04  patch_amp=5.135e-04
# t= 510  var_x=2.292e-09  vac_E=1.581e-13  max_amp=5.121e-04  patch_amp=5.104e-04
# t= 520  var_x=2.282e-09  vac_E=1.080e-13  max_amp=5.091e-04  patch_amp=5.076e-04
# t= 530  var_x=2.274e-09  vac_E=7.436e-14  max_amp=5.064e-04  patch_amp=5.050e-04
# t= 540  var_x=2.267e-09  vac_E=5.168e-14  max_amp=5.039e-04  patch_amp=5.026e-04
# t= 550  var_x=2.260e-09  vac_E=3.623e-14  max_amp=5.016e-04  patch_amp=5.004e-04
# t= 560  var_x=2.254e-09  vac_E=2.561e-14  max_amp=4.995e-04  patch_amp=4.984e-04
# t= 570  var_x=2.249e-09  vac_E=1.829e-14  max_amp=4.976e-04  patch_amp=4.965e-04
# t= 580  var_x=2.244e-09  vac_E=1.332e-14  max_amp=4.958e-04  patch_amp=4.947e-04
# t= 590  var_x=2.240e-09  vac_E=1.001e-14  max_amp=4.941e-04  patch_amp=4.931e-04
# t= 600  var_x=2.236e-09  vac_E=7.720e-15  max_amp=4.926e-04  patch_amp=4.917e-04
# t= 610  var_x=2.233e-09  vac_E=6.058e-15  max_amp=4.911e-04  patch_amp=4.903e-04
# t= 620  var_x=2.230e-09  vac_E=4.836e-15  max_amp=4.898e-04  patch_amp=4.890e-04
# t= 630  var_x=2.227e-09  vac_E=3.944e-15  max_amp=4.886e-04  patch_amp=4.879e-04
# t= 640  var_x=2.225e-09  vac_E=3.268e-15  max_amp=4.875e-04  patch_amp=4.868e-04
# t= 650  var_x=2.223e-09  vac_E=2.755e-15  max_amp=4.864e-04  patch_amp=4.858e-04
# t= 660  var_x=2.221e-09  vac_E=2.360e-15  max_amp=4.855e-04  patch_amp=4.848e-04
# t= 670  var_x=2.219e-09  vac_E=2.034e-15  max_amp=4.846e-04  patch_amp=4.840e-04
# t= 680  var_x=2.217e-09  vac_E=1.767e-15  max_amp=4.837e-04  patch_amp=4.832e-04
# t= 690  var_x=2.216e-09  vac_E=1.549e-15  max_amp=4.829e-04  patch_amp=4.824e-04
# t= 700  var_x=2.215e-09  vac_E=1.364e-15  max_amp=4.822e-04  patch_amp=4.817e-04
# t= 710  var_x=2.214e-09  vac_E=1.205e-15  max_amp=4.815e-04  patch_amp=4.810e-04
# t= 720  var_x=2.213e-09  vac_E=1.069e-15  max_amp=4.809e-04  patch_amp=4.804e-04
# t= 730  var_x=2.212e-09  vac_E=9.492e-16  max_amp=4.803e-04  patch_amp=4.799e-04
# t= 740  var_x=2.211e-09  vac_E=8.448e-16  max_amp=4.798e-04  patch_amp=4.793e-04
# t= 750  var_x=2.210e-09  vac_E=7.528e-16  max_amp=4.792e-04  patch_amp=4.788e-04
# t= 760  var_x=2.210e-09  vac_E=6.715e-16  max_amp=4.788e-04  patch_amp=4.784e-04
# t= 770  var_x=2.209e-09  vac_E=5.994e-16  max_amp=4.783e-04  patch_amp=4.780e-04
# t= 780  var_x=2.209e-09  vac_E=5.352e-16  max_amp=4.779e-04  patch_amp=4.776e-04
# t= 790  var_x=2.208e-09  vac_E=4.782e-16  max_amp=4.775e-04  patch_amp=4.772e-04
# t= 800  var_x=2.208e-09  vac_E=4.274e-16  max_amp=4.771e-04  patch_amp=4.768e-04
# t= 810  var_x=2.207e-09  vac_E=3.820e-16  max_amp=4.768e-04  patch_amp=4.765e-04
# t= 820  var_x=2.207e-09  vac_E=3.415e-16  max_amp=4.764e-04  patch_amp=4.762e-04
# t= 830  var_x=2.207e-09  vac_E=3.054e-16  max_amp=4.761e-04  patch_amp=4.759e-04
# t= 840  var_x=2.206e-09  vac_E=2.731e-16  max_amp=4.759e-04  patch_amp=4.756e-04
# t= 850  var_x=2.206e-09  vac_E=2.442e-16  max_amp=4.756e-04  patch_amp=4.754e-04
# t= 860  var_x=2.206e-09  vac_E=2.184e-16  max_amp=4.753e-04  patch_amp=4.751e-04
# t= 870  var_x=2.206e-09  vac_E=1.953e-16  max_amp=4.751e-04  patch_amp=4.749e-04
# t= 880  var_x=2.206e-09  vac_E=1.747e-16  max_amp=4.749e-04  patch_amp=4.747e-04
# t= 890  var_x=2.206e-09  vac_E=1.562e-16  max_amp=4.747e-04  patch_amp=4.745e-04
# t= 900  var_x=2.205e-09  vac_E=1.397e-16  max_amp=4.745e-04  patch_amp=4.743e-04
# t= 910  var_x=2.205e-09  vac_E=1.250e-16  max_amp=4.743e-04  patch_amp=4.741e-04
# t= 920  var_x=2.205e-09  vac_E=1.118e-16  max_amp=4.741e-04  patch_amp=4.740e-04
# t= 930  var_x=2.205e-09  vac_E=9.999e-17  max_amp=4.739e-04  patch_amp=4.738e-04
# t= 940  var_x=2.205e-09  vac_E=8.943e-17  max_amp=4.738e-04  patch_amp=4.737e-04
# t= 950  var_x=2.205e-09  vac_E=7.999e-17  max_amp=4.737e-04  patch_amp=4.735e-04
# t= 960  var_x=2.205e-09  vac_E=7.155e-17  max_amp=4.735e-04  patch_amp=4.734e-04
# t= 970  var_x=2.205e-09  vac_E=6.400e-17  max_amp=4.734e-04  patch_amp=4.733e-04
# t= 980  var_x=2.205e-09  vac_E=5.724e-17  max_amp=4.733e-04  patch_amp=4.732e-04
# t= 990  var_x=2.205e-09  vac_E=5.120e-17  max_amp=4.732e-04  patch_amp=4.731e-04
# t= 999  var_x=2.205e-09  vac_E=4.631e-17  max_amp=4.731e-04  patch_amp=4.730e-04
# Evolution complete.
# --- QFT2001c qualitative checks ---
# Final vacuum variance: 2.204664595917483e-09
# Final vacuum energy proxy: 4.6309176510807105e-17
# Final global max amplitude: 0.0004730574247283373
# Final local patch amplitude: 0.0004729608211909386
# Mode spectra samples: 101 snapshots
