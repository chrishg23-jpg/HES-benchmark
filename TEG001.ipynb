# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/TEG001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧬 TEG001: Tensorial Emergence Genesis
# Simulates attractor motion in a tensorial curvature field using entropic principles
# Author: Chris & Copilot | Arc VIII: Tensorial Emergence

import numpy as np
import matplotlib.pyplot as plt

# 📐 Curvature Tensor Module
def curvature_tensor(x, y, sigma=1.0):
    exp_term = np.exp(-(x**2 + y**2) / (2 * sigma**2))
    Cxx = (1 - x**2 / sigma**2) * exp_term
    Cyy = (1 - y**2 / sigma**2) * exp_term
    Cxy = (-x * y / sigma**2) * exp_term
    return np.array([[Cxx, Cxy], [Cxy, Cyy]])

# 🧲 Tensor-Contraction Force
def tensor_force(x, y, vx, vy, sigma=1.0):
    C = curvature_tensor(x, y, sigma)
    v = np.array([vx, vy])
    f = -np.dot(C, v)
    return f[0], f[1]

# 🔁 Velocity Update Rule (Entropic)
def update_velocity(vx, vy, fx, fy, dt):
    return vx + fx * dt, vy + fy * dt

# 🧠 Directional Memory Coupling (Placeholder)
def update_memory_field(x, y, vx, vy, memory_field):
    # To be implemented: evolve memory vector field M_i(x, y)
    return memory_field

# 🚀 Simulation Loop
def simulate_tensorial_orbit(x0, y0, vx0, vy0, steps=10000, dt=0.01, sigma=1.0):
    x, y = x0, y0
    vx, vy = vx0, vy0
    trajectory = []

    # Initialize memory field (placeholder)
    memory_field = np.zeros((steps, 2))

    for i in range(steps):
        fx, fy = tensor_force(x, y, vx, vy, sigma)
        vx, vy = update_velocity(vx, vy, fx, fy, dt)
        x += vx * dt
        y += vy * dt
        trajectory.append((x, y))
        memory_field[i] = update_memory_field(x, y, vx, vy, memory_field[i-1] if i > 0 else np.array([0, 0]))

    return np.array(trajectory), memory_field

# 📊 Plotting Utility
def plot_trajectory(trajectory):
    x_vals, y_vals = trajectory[:,0], trajectory[:,1]
    plt.figure(figsize=(8, 8))
    plt.plot(x_vals, y_vals, linewidth=1.5)
    plt.title("TEG001: Tensorial Orbit Trajectory")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.grid(True)
    plt.axis('equal')
    plt.show()

# 🧪 Run Example
trajectory, memory = simulate_tensorial_orbit(x0=1.0, y0=0.0, vx0=0.0, vy0=0.5, steps=5000, dt=0.01, sigma=1.0)
plot_trajectory(trajectory)
