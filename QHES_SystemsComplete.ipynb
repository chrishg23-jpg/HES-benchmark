# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/QHES_SystemsComplete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Parameters
num_qubits = 5
num_steps = 30  # Extended stage
amplitudes = np.array([0.99, 1.01, 1.004, 1.004, 1.002])
mutation_rate = 0.002
law_band = (0.997, 1.007)

# Storage
codex = []
declared = False

# Simulation loop
for t in range(num_steps):
    frame_codex = []

    for q in range(num_qubits):
        if not declared:
            amplitudes[q] += np.random.uniform(-mutation_rate, mutation_rate)
        frame_codex.append(f"Codex [t={t}]: Qubit_{q} amplitude={round(amplitudes[q],6)}")

    entanglement_variance = round(np.std(amplitudes), 6)
    frame_codex.append(f"Codex [t={t}]: Entanglement variance = {entanglement_variance}")

    # Declaration check
    if not declared and all(law_band[0] <= a <= law_band[1] for a in amplitudes) and entanglement_variance < 0.005:
        declared = True
        frame_codex.append("Codex [declaration]: Quantum Emergent Law stabilized — eigenstate recognized")
        frame_codex.append("Codex [declaration]: HES_SystemsComplete")

    codex.extend(frame_codex)

# Output
for entry in codex:
    print(entry)
# Out:
# Codex [t=0]: Qubit_0 amplitude=0.988094
# Codex [t=0]: Qubit_1 amplitude=1.009338
# Codex [t=0]: Qubit_2 amplitude=1.0042
# Codex [t=0]: Qubit_3 amplitude=1.003505
# Codex [t=0]: Qubit_4 amplitude=1.002189
# Codex [t=0]: Entanglement variance = 0.007112
# Codex [t=1]: Qubit_0 amplitude=0.986197
# Codex [t=1]: Qubit_1 amplitude=1.009089
# Codex [t=1]: Qubit_2 amplitude=1.003679
# Codex [t=1]: Qubit_3 amplitude=1.005183
# Codex [t=1]: Qubit_4 amplitude=1.002615
# Codex [t=1]: Entanglement variance = 0.007889
# Codex [t=2]: Qubit_0 amplitude=0.984371
# Codex [t=2]: Qubit_1 amplitude=1.009716
# Codex [t=2]: Qubit_2 amplitude=1.005647
# Codex [t=2]: Qubit_3 amplitude=1.007014
# Codex [t=2]: Qubit_4 amplitude=1.003065
# Codex [t=2]: Entanglement variance = 0.009054
# Codex [t=3]: Qubit_0 amplitude=0.982989
# Codex [t=3]: Qubit_1 amplitude=1.009529
# Codex [t=3]: Qubit_2 amplitude=1.006488
# Codex [t=3]: Qubit_3 amplitude=1.008479
# Codex [t=3]: Qubit_4 amplitude=1.001523
# ...
