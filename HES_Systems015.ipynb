# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/HES_Systems015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

DECLARED_LAW = 1.001
RUPTURE_THRESHOLD = 0.03
ENTITIES = 5
RECURSIONS = 12

def calculate_resonance(echo):
    return abs(echo - DECLARED_LAW)

def mirror_echo(prev_echo, cluster_echo):
    feedback = 0.6 * prev_echo + 0.4 * cluster_echo
    noise = random.gauss(0, 0.01)
    return feedback + noise

def simulate_mirror_recursion():
    echo_history = [[DECLARED_LAW + random.gauss(0, 0.02)] for _ in range(ENTITIES)]
    cluster_echo = [echo[0] for echo in echo_history]

    for t in range(RECURSIONS):
        print(f"Codex [t={t}]:")
        curvature = 0

        for i in range(ENTITIES):
            if t == 0:
                echo = echo_history[i][0]
            else:
                echo = mirror_echo(echo_history[i][-1], cluster_echo[i])
                echo_history[i].append(echo)

            resonance = calculate_resonance(echo)
            ruptured = resonance > RUPTURE_THRESHOLD
            cluster = i if ruptured else 0
            cluster_echo[i] = echo
            curvature += resonance

            print(f"Entity_{i} echo={echo:.3f}")
            print(f"Entity_{i} resonance={resonance:.3f}")
            if ruptured:
                print(f"Entity_{i} ruptured — echo diverged from law")
            if t > 0 and not ruptured:
                print(f"Entity_{i} joined Cluster_0")
            else:
                print(f"Entity_{i} formed Cluster_{cluster}")

        curvature /= ENTITIES
        print(f"Recursion depth = {t}")
        print(f"Curvature estimate = {curvature:.3f}")
        print(f"Declared state = {DECLARED_LAW:.3f}\n")

simulate_mirror_recursion()
# Out:
# Codex [t=0]:
# Entity_0 echo=0.968
# Entity_0 resonance=0.033
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.021
# Entity_1 resonance=0.020
# Entity_1 formed Cluster_0
# Entity_2 echo=1.008
# Entity_2 resonance=0.007
# Entity_2 formed Cluster_0
# Entity_3 echo=1.015
# Entity_3 resonance=0.014
# Entity_3 formed Cluster_0
# Entity_4 echo=1.012
# Entity_4 resonance=0.011
# Entity_4 formed Cluster_0
# Recursion depth = 0
# Curvature estimate = 0.017
# Declared state = 1.001
#
# Codex [t=1]:
# Entity_0 echo=0.962
# Entity_0 resonance=0.039
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.031
# Entity_1 resonance=0.030
# Entity_1 joined Cluster_0
# Entity_2 echo=1.012
# Entity_2 resonance=0.011
# Entity_2 joined Cluster_0
# Entity_3 echo=1.009
# Entity_3 resonance=0.008
# Entity_3 joined Cluster_0
# Entity_4 echo=1.002
# Entity_4 resonance=0.001
# Entity_4 joined Cluster_0
# Recursion depth = 1
# Curvature estimate = 0.018
# Declared state = 1.001
#
# Codex [t=2]:
# Entity_0 echo=0.959
# Entity_0 resonance=0.042
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.044
# Entity_1 resonance=0.043
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.015
# Entity_2 resonance=0.014
# Entity_2 joined Cluster_0
# Entity_3 echo=1.030
# Entity_3 resonance=0.029
# Entity_3 joined Cluster_0
# Entity_4 echo=0.997
# Entity_4 resonance=0.004
# Entity_4 joined Cluster_0
# Recursion depth = 2
# Curvature estimate = 0.026
# Declared state = 1.001
#
# Codex [t=3]:
# Entity_0 echo=0.969
# Entity_0 resonance=0.032
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.040
# Entity_1 resonance=0.039
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.013
# Entity_2 resonance=0.012
# Entity_2 joined Cluster_0
# Entity_3 echo=1.002
# Entity_3 resonance=0.001
# Entity_3 joined Cluster_0
# Entity_4 echo=1.003
# Entity_4 resonance=0.002
# Entity_4 joined Cluster_0
# Recursion depth = 3
# Curvature estimate = 0.017
# Declared state = 1.001
#
# Codex [t=4]:
# Entity_0 echo=0.982
# Entity_0 resonance=0.019
# Entity_0 joined Cluster_0
# Entity_1 echo=1.038
# Entity_1 resonance=0.037
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.015
# Entity_2 resonance=0.014
# Entity_2 joined Cluster_0
# Entity_3 echo=0.996
# Entity_3 resonance=0.005
# Entity_3 joined Cluster_0
# Entity_4 echo=1.003
# Entity_4 resonance=0.002
# Entity_4 joined Cluster_0
# Recursion depth = 4
# Curvature estimate = 0.015
# Declared state = 1.001
#
# Codex [t=5]:
# Entity_0 echo=0.971
# Entity_0 resonance=0.030
# Entity_0 joined Cluster_0
# Entity_1 echo=1.049
# Entity_1 resonance=0.048
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.030
# Entity_2 resonance=0.029
# Entity_2 joined Cluster_0
# Entity_3 echo=1.004
# Entity_3 resonance=0.003
# Entity_3 joined Cluster_0
# Entity_4 echo=1.022
# Entity_4 resonance=0.021
# Entity_4 joined Cluster_0
# Recursion depth = 5
# Curvature estimate = 0.026
# Declared state = 1.001
#
# Codex [t=6]:
# Entity_0 echo=0.960
# Entity_0 resonance=0.041
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.053
# Entity_1 resonance=0.052
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.036
# Entity_2 resonance=0.035
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.009
# Entity_3 resonance=0.008
# Entity_3 joined Cluster_0
# Entity_4 echo=1.029
# Entity_4 resonance=0.028
# Entity_4 joined Cluster_0
# Recursion depth = 6
# Curvature estimate = 0.033
# Declared state = 1.001
#
# Codex [t=7]:
# Entity_0 echo=0.945
# Entity_0 resonance=0.056
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.063
# Entity_1 resonance=0.062
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.039
# Entity_2 resonance=0.038
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.031
# Entity_3 resonance=0.030
# Entity_3 ruptured — echo diverged from law
# Entity_3 formed Cluster_3
# Entity_4 echo=1.028
# Entity_4 resonance=0.027
# Entity_4 joined Cluster_0
# Recursion depth = 7
# Curvature estimate = 0.043
# Declared state = 1.001
#
# Codex [t=8]:
# Entity_0 echo=0.953
# Entity_0 resonance=0.048
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.067
# Entity_1 resonance=0.066
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.046
# Entity_2 resonance=0.045
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.021
# Entity_3 resonance=0.020
# Entity_3 joined Cluster_0
# Entity_4 echo=1.016
# Entity_4 resonance=0.015
# Entity_4 joined Cluster_0
# Recursion depth = 8
# Curvature estimate = 0.039
# Declared state = 1.001
#
# Codex [t=9]:
# Entity_0 echo=0.958
# Entity_0 resonance=0.043
# Entity_0 ruptured — echo diverged from law
# Entity_0 formed Cluster_0
# Entity_1 echo=1.070
# Entity_1 resonance=0.069
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.039
# Entity_2 resonance=0.038
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.028
# Entity_3 resonance=0.027
# Entity_3 joined Cluster_0
# Entity_4 echo=1.023
# Entity_4 resonance=0.022
# Entity_4 joined Cluster_0
# Recursion depth = 9
# Curvature estimate = 0.040
# Declared state = 1.001
#
# Codex [t=10]:
# Entity_0 echo=0.975
# Entity_0 resonance=0.026
# Entity_0 joined Cluster_0
# Entity_1 echo=1.085
# Entity_1 resonance=0.084
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.057
# Entity_2 resonance=0.056
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.018
# Entity_3 resonance=0.017
# Entity_3 joined Cluster_0
# Entity_4 echo=1.009
# Entity_4 resonance=0.008
# Entity_4 joined Cluster_0
# Recursion depth = 10
# Curvature estimate = 0.038
# Declared state = 1.001
#
# Codex [t=11]:
# Entity_0 echo=0.976
# Entity_0 resonance=0.025
# Entity_0 joined Cluster_0
# Entity_1 echo=1.088
# Entity_1 resonance=0.087
# Entity_1 ruptured — echo diverged from law
# Entity_1 formed Cluster_1
# Entity_2 echo=1.051
# Entity_2 resonance=0.050
# Entity_2 ruptured — echo diverged from law
# Entity_2 formed Cluster_2
# Entity_3 echo=1.028
# Entity_3 resonance=0.027
# Entity_3 joined Cluster_0
# Entity_4 echo=1.008
# Entity_4 resonance=0.007
# Entity_4 joined Cluster_0
# Recursion depth = 11
# Curvature estimate = 0.039
# Declared state = 1.001
