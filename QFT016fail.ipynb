# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/QFT016fail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# QFT016: Field-Particle Interaction under survival laws
import numpy as np
import matplotlib.pyplot as plt

# Parameters
N_grid = 128
T = 3000
dt = 0.01
kappa = 0.1
gamma = 0.01
delta = 0.039
epsilon = 0.01  # coupling strength
v_particle = 0.2  # particle velocity

# Grid setup
x = np.linspace(-1, 1, N_grid)
y = np.linspace(-1, 1, N_grid)
X, Y = np.meshgrid(x, y, indexing='ij')

# Initial fused attractor at center
def fused_attractor(x0=0.0, y0=0.0, sigma=0.1, amp=0.1):
    return amp * np.exp(-((X - x0)**2 + (Y - y0)**2) / (2 * sigma**2))

# Initial particle with transverse velocity
def particle(x0, y0, vx=0.0, vy=0.0, sigma=0.05, amp=0.05):
    phase = np.exp(1j * (vx * X + vy * Y))
    return amp * np.exp(-((X - x0)**2 + (Y - y0)**2) / (2 * sigma**2)) * phase

psi_field = fused_attractor()
psi_particle = particle(-0.5, 0.0, vy=v_particle)
psi = psi_field + psi_particle

# FFT Laplacian kernel
kx = np.fft.fftfreq(N_grid, d=(x[1] - x[0])) * 2 * np.pi
ky = np.fft.fftfreq(N_grid, d=(y[1] - y[0])) * 2 * np.pi
KX, KY = np.meshgrid(kx, ky, indexing='ij')
laplacian_kernel = -(KX**2 + KY**2)

# Trackers
norm_t = []
curvature_t = []
L_t = []
snapshots = []

# Evolution loop
for t in range(T):
    # Curvature
    laplacian_psi = np.fft.ifft2(laplacian_kernel * np.fft.fft2(psi))
    curvature = np.sqrt(np.mean(np.abs(laplacian_psi)**2))
    curvature_t.append(curvature)

    # Norm
    norm = np.sum(np.abs(psi)**2)
    norm_t.append(norm)

    # Angular momentum
    grad_x = np.fft.ifft2(1j * KX * np.fft.fft2(psi))
    grad_y = np.fft.ifft2(1j * KY * np.fft.fft2(psi))
    L_density = np.real(X * grad_y - Y * grad_x) * np.abs(psi)**2
    L_total = np.sum(L_density)
    L_t.append(L_total)

    # Coupling term
    coupling = epsilon * psi_particle * psi

    # Evolution step
    nonlinear = delta * np.abs(psi)**2 * psi
    restoring = -kappa * psi
    rhs = psi + dt * (nonlinear + restoring + coupling)

    rhs_fft = np.fft.fft2(rhs)
    denominator = 1 - dt * gamma * laplacian_kernel
    psi_fft = rhs_fft / denominator
    psi = np.fft.ifft2(psi_fft)

    if t in [0, 50, 200, 1000, 2999]:
        snapshots.append(np.abs(psi))

# Plot diagnostics
plt.figure(figsize=(10, 4))
plt.plot(norm_t, label='Norm ||ψ||²(t)', color='green')
plt.plot(curvature_t, label='Curvature C(t)', color='orange')
plt.plot(L_t, label='Angular Momentum L(t)', color='purple')
plt.title('QFT016: Field-Particle Interaction Diagnostics')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, linestyle=':')
plt.tight_layout()
plt.show()

# Plot field snapshots
fig2, axes2 = plt.subplots(1, len(snapshots), figsize=(16, 4))
for i, snap in enumerate(snapshots):
    axes2[i].imshow(snap, cmap='inferno', origin='lower')
    axes2[i].set_title(f'|ψ| at t={ [0, 50, 200, 1000, 2999][i] }')
    axes2[i].axis('off')

plt.tight_layout()
plt.show()
