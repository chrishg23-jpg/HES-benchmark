# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/EmergentRegulator002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# Parameters
N = 100              # Number of spatial points
T = 20               # Short run for early-time focus
x = np.linspace(0, 1, N)
v0 = np.sin(2 * np.pi * x)  # Structured initial velocity

# Curvature field generator
def curvature_field(strength=0.0):
    return strength * np.exp(-((x - 0.5)**2) / 0.01)

# Evolution function with curvature-modulated noise
def evolve(v_init, curvature, steps):
    traj = [v_init.copy()]
    v = v_init.copy()
    for _ in range(steps):
        noise = np.random.randn(N) * (1.0 / (1.0 + curvature))
        v += noise
        traj.append(v.copy())
    return np.array(traj)

# Entropy metric (velocity dispersion)
def entropy_metric(traj):
    return [np.std(v) for v in traj]

# Curvature strengths to test
curvatures = [0.0, 2.0, 5.0]
labels = ["Flat Space", "Moderate Curvature", "Strong Curvature"]
colors = ["red", "orange", "green"]

# Plotting
plt.figure(figsize=(10, 6))
for strength, label, color in zip(curvatures, labels, colors):
    C = curvature_field(strength)
    traj = evolve(v0, C, T)
    entropy = entropy_metric(traj)
    plt.plot(entropy, label=label, color=color)

plt.title("Early-Time Entropy vs. Curvature")
plt.xlabel("Time Step")
plt.ylabel("Velocity Dispersion (Entropy)")
plt.legend()
plt.tight_layout()
plt.show()
