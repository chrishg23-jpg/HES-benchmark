# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/Cosmo003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# -------------------------------
# Step 1: Nonlinear Amplification Model
# -------------------------------
def nonlinear_inflation(delta, kappa, steps=100):
    """
    Simulate expansion with curvature-coupled entropic feedback.
    Returns expansion profile and inflation metrics.
    """
    gradient = delta - kappa
    expansion = np.zeros(steps)
    entropy = np.zeros(steps)
    feedback = 1.0

    for t in range(steps):
        curvature = np.sin(delta * t / steps) + np.cos(kappa * t / steps)
        feedback *= (1 + gradient * curvature / (1 + t))  # nonlinear amplification
        expansion[t] = np.exp(feedback * gradient * t / steps)
        entropy[t] = np.log1p(expansion[t]) / (1 + t)

    inflation_rate = expansion[10] / expansion[0]
    exit_slope = expansion[-1] - expansion[-2]
    return expansion, entropy, inflation_rate, exit_slope

# -------------------------------
# Step 2: Sweep δ and κ
# -------------------------------
delta_values = np.linspace(0.6, 0.8, 10)
kappa_values = np.linspace(0.6, 0.8, 10)

print("🪐 Act XXXV: Nonlinear Entropic Amplification")
for delta in delta_values:
    for kappa in kappa_values:
        expansion, entropy, inflation_rate, exit_slope = nonlinear_inflation(delta, kappa)
        label = "✓" if inflation_rate > 2.0 else "–"
        print(f"{label} δ = {delta:.4f}, κ = {kappa:.4f}, δ−κ = {delta - kappa:+.4f} | Inflation Rate = {inflation_rate:.2f}, Exit Slope = {exit_slope:.4f}")
# Out:
# 🪐 Act XXXV: Nonlinear Entropic Amplification
# – δ = 0.6000, κ = 0.6000, δ−κ = +0.0000 | Inflation Rate = 1.00, Exit Slope = 0.0000
# – δ = 0.6000, κ = 0.6222, δ−κ = -0.0222 | Inflation Rate = 1.00, Exit Slope = -0.0002
# – δ = 0.6000, κ = 0.6444, δ−κ = -0.0444 | Inflation Rate = 1.00, Exit Slope = -0.0003
# – δ = 0.6000, κ = 0.6667, δ−κ = -0.0667 | Inflation Rate = 0.99, Exit Slope = -0.0004
# – δ = 0.6000, κ = 0.6889, δ−κ = -0.0889 | Inflation Rate = 0.99, Exit Slope = -0.0004
# – δ = 0.6000, κ = 0.7111, δ−κ = -0.1111 | Inflation Rate = 0.99, Exit Slope = -0.0005
# – δ = 0.6000, κ = 0.7333, δ−κ = -0.1333 | Inflation Rate = 0.99, Exit Slope = -0.0005
# – δ = 0.6000, κ = 0.7556, δ−κ = -0.1556 | Inflation Rate = 0.99, Exit Slope = -0.0005
# – δ = 0.6000, κ = 0.7778, δ−κ = -0.1778 | Inflation Rate = 0.99, Exit Slope = -0.0005
# – δ = 0.6000, κ = 0.8000, δ−κ = -0.2000 | Inflation Rate = 0.99, Exit Slope = -0.0004
# ...
