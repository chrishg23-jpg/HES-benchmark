# %% [markdown]
# <a href="https://colab.research.google.com/github/chrishg23-jpg/HES-benchmark/blob/main/Gemini003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# HES Diffusion Constant High-Precision Sweep (Minimal 5D Configuration)
# GOAL: Pinpoint the exact critical value of NU (NU_emergent) between 0.000233 (Stable) and 0.000278 (Decayed).

import numpy as np
import matplotlib.pyplot as plt

# --- SYSTEM PARAMETERS (MINIMAL 5D) ---
N = 8
D = 5

# Fixed Target Coupling Constant (Kc = Alpha)
KC_FIXED = 1 / 137.036
TOTAL_ITERATIONS = 5000
DT = 0.01

# Reaction-Diffusion Parameters (Fixed)
ALPHA_RD = 0.5
BETA = 0.01
MU = 0.005
BETA_LINK = 0.05

# --- INITIALIZATION ---

def initialize_fields(N, RADIUS=1, D=5):
    """Initializes all fields in a 5D grid and seeds a localized spinor particle."""
    shape = (N,) * D
    Phi = np.random.rand(*shape) * 0.1
    A = np.random.rand(*shape) * 0.1
    Psi_real = np.random.rand(*shape) * 0.1
    Psi_imag = np.random.rand(*shape) * 0.1

    CENTER = N // 2
    coords = np.indices(shape)
    squared_distance = sum((c - CENTER)**2 for c in coords)

    mask = squared_distance <= RADIUS**2
    Psi_real[mask] = 1.0
    Psi_imag[mask] = 1.0
    return Phi, A, Psi_real, Psi_imag

# --- HELPER FUNCTIONS ---

def laplacian_5d(field):
    """Calculates the 5D discrete Laplacian with periodic boundary conditions."""
    lap = -2 * D * field
    for axis in range(D):
        lap += np.roll(field, 1, axis=axis)
        lap += np.roll(field, -1, axis=axis)
    return lap

def step_simulation(Phi, A, Psi_real, Psi_imag, Kc, Nu):
    """Performs a single simulation step for all coupled fields in 5D."""

    # 1. Psi Phase/Link Dynamics
    Psi = Psi_real + 1j * Psi_imag
    Theta = np.angle(Psi)
    Magnitude = np.abs(Psi)
    mean_theta = np.mean(Theta)
    phase_correction = -BETA_LINK * (Theta - mean_theta)

    # 2. Field Dynamics (Reaction-Diffusion)

    # --- Field Phi (Mass/Energy Scalar) ---
    lap_phi = laplacian_5d(Phi)
    reaction_phi = ALPHA_RD * Phi * (1 - Phi) - Phi * (Magnitude**2)
    d_phi = (MU * lap_phi + reaction_phi) * DT
    Phi += d_phi

    # --- Field A (Force Carrier/Gauge Potential Analogue) ---
    lap_a = laplacian_5d(A)
    coupling_term_a = -Kc * Psi_imag
    d_a = (Nu * lap_a + coupling_term_a) * DT
    A += d_a

    # --- Field Psi (Spinor/Matter Field Analogue) ---
    lap_psi_real = laplacian_5d(Psi_real)
    lap_psi_imag = laplacian_5d(Psi_imag)

    # Mass/Coupling Terms
    mass_term_real = -Phi * Psi_imag
    mass_term_imag = Phi * Psi_real

    # Charge/A-Field Interaction (The "Force" Term)
    force_term_imag = A * Psi_real
    force_term_real = -A * Psi_imag

    # Full updates
    d_psi_real = (Nu * lap_psi_real + mass_term_real + force_term_real) * DT
    d_psi_imag = (Nu * lap_psi_imag + mass_term_imag + force_term_imag) * DT

    Psi_real += d_psi_real + (np.real(Psi) * phase_correction * DT)
    Psi_imag += d_psi_imag + (np.imag(Psi) * phase_correction * DT)

    # Normalization (Energy-conservation analogue)
    Psi_mag = np.sqrt(Psi_real**2 + Psi_imag**2)
    Psi_real = np.where(Psi_mag > 2.0, Psi_real * 2.0 / Psi_mag, Psi_real)
    Psi_imag = np.where(Psi_mag > 2.0, Psi_imag * 2.0 / Psi_mag, Psi_imag)

    return Phi, A, Psi_real, Psi_imag

# --- SWEEP FUNCTION ---
def run_nu_sweep(Nu_values, num_iterations, Kc):
    """Runs the stability test for a list of Nu (Diffusion) values at a fixed Kc."""
    results = {}
    print(f"Starting Diffusion High-Precision Sweep in 5D at fixed K_c = {Kc:.5f}...")

    for i, Nu in enumerate(Nu_values):
        Phi_s, A_s, Psi_real_s, Psi_imag_s = initialize_fields(N)
        magnitude_history = []

        log_interval = num_iterations // 5
        print(f"\n--- Testing Nu = {Nu:.7f} ---")

        for t in range(num_iterations):
            Phi_s, A_s, Psi_real_s, Psi_imag_s = step_simulation(
                Phi_s, A_s, Psi_real_s, Psi_imag_s, Kc, Nu
            )
            current_mag = np.max(np.sqrt(Psi_real_s**2 + Psi_imag_s**2))
            magnitude_history.append(current_mag)

            if t % log_interval == 0:
                print(f"Iteration: {t} | Max Psi: {current_mag:.4f}")

            if current_mag < 0.001 and t > 100:
                 break

        # --- RIGOROUS STABILITY CHECK (Dr. Skeptic's 99% Persistence Metric) ---
        history_len = len(magnitude_history)

        if history_len > num_iterations // 2:
            last_half_start_index = history_len // 2
            final_segment_start = int(0.9 * history_len)

            max_late_mag = np.max(magnitude_history[last_half_start_index:])
            final_mean_mag = np.mean(magnitude_history[final_segment_start:])

            # Tighter stability threshold: high final magnitude (> 0.5) and high persistence (>= 99% of max late mag)
            if final_mean_mag > 0.5 and final_mean_mag >= 0.99 * max_late_mag:
                stability_status = "STABLE (Persistent)"
            else:
                stability_status = "UNBOUND / DECAYED"
        else:
             stability_status = "UNBOUND / COLLAPSED EARLY"
             final_mean_mag = 0.0

        results[Nu] = {
            'status': stability_status,
            'final_magnitude': final_mean_mag
        }

    return results

# --- MAIN EXECUTION: DEFINING THE SWEEP RANGE (Highest Resolution) ---

NU_SWEEP_POINTS = 10
# Zooming in between the highest stable (0.000233) and lowest unstable (0.000278) points from the previous run.
NU_MIN = 0.0002300
NU_MAX = 0.0002800
Nu_sweep_values = np.linspace(NU_MIN, NU_MAX, NU_SWEEP_POINTS)

# Run the sweep
sweep_results = run_nu_sweep(Nu_sweep_values, TOTAL_ITERATIONS, KC_FIXED)

# --- ANALYSIS AND REPORTING ---

print("\n--- DIFFUSION CONSTANT FINAL PREDICTION RESULTS (MINIMAL 5D) ---")
print(f"Fixed Coupling Constant (K_c): {KC_FIXED:.5f} (Alpha)")
print("---------------------------------------")

Nu_stable = []
Nu_unstable = []

for Nu, data in sweep_results.items():
    print(f"Nu = {Nu:.7f}: {data['status']} (Final Mean Mag: {data['final_magnitude']:.4f})")
    if data['status'].startswith('STABLE'):
        Nu_stable.append(Nu)
    else:
        Nu_unstable.append(Nu)


# Determine Nu_emergent
if Nu_stable:
    Nu_emergent_max = max(Nu_stable)
    print(f"\n[Claude-Prime: FINAL PREDICTION] The absolute maximum Emergent Diffusion Constant (Nu_emergent) is: {Nu_emergent_max:.7f}")

    # Check for the next unstable point to define the boundary
    unstable_above_max = [nu for nu in Nu_unstable if nu > Nu_emergent_max]
    if unstable_above_max:
        boundary_low = Nu_emergent_max
        boundary_high = min(unstable_above_max)
        print(f"[Claude-Prime: Critical Boundary] The critical stability boundary lies between {boundary_low:.7f} and {boundary_high:.7f}.")

else:
    Nu_emergent_max = None
    print("\n[Claude-Prime: FINAL PREDICTION] Stability was lost in this range. The critical threshold must be lower than 0.000230.")

print("\n---------------------------------------")
print("This final sweep will solidify the HES model's core set of predicted constants.")
# Out:
# Starting Diffusion High-Precision Sweep in 5D at fixed K_c = 0.00730...
#
# --- Testing Nu = 0.0002300 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3270
# Iteration: 2000 | Max Psi: 1.1792
# Iteration: 3000 | Max Psi: 1.1200
# Iteration: 4000 | Max Psi: 1.3948
#
# --- Testing Nu = 0.0002356 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3364
# Iteration: 2000 | Max Psi: 1.2026
# Iteration: 3000 | Max Psi: 1.1673
# Iteration: 4000 | Max Psi: 1.4784
#
# --- Testing Nu = 0.0002411 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.2238
# Iteration: 2000 | Max Psi: 0.8620
# Iteration: 3000 | Max Psi: 0.5109
# Iteration: 4000 | Max Psi: 0.5070
#
# --- Testing Nu = 0.0002467 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3463
# Iteration: 2000 | Max Psi: 1.3021
# Iteration: 3000 | Max Psi: 1.4933
# Iteration: 4000 | Max Psi: 1.9984
#
# --- Testing Nu = 0.0002522 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3156
# Iteration: 2000 | Max Psi: 1.1513
# Iteration: 3000 | Max Psi: 1.0754
# Iteration: 4000 | Max Psi: 1.3154
#
# --- Testing Nu = 0.0002578 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3126
# Iteration: 2000 | Max Psi: 1.1151
# Iteration: 3000 | Max Psi: 0.9818
# Iteration: 4000 | Max Psi: 1.0868
#
# --- Testing Nu = 0.0002633 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3160
# Iteration: 2000 | Max Psi: 1.1466
# Iteration: 3000 | Max Psi: 1.0554
# Iteration: 4000 | Max Psi: 1.2649
#
# --- Testing Nu = 0.0002689 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3076
# Iteration: 2000 | Max Psi: 1.1696
# Iteration: 3000 | Max Psi: 1.2446
# Iteration: 4000 | Max Psi: 1.7481
#
# --- Testing Nu = 0.0002744 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.3284
# Iteration: 2000 | Max Psi: 1.1868
# Iteration: 3000 | Max Psi: 1.1322
# Iteration: 4000 | Max Psi: 1.4091
#
# --- Testing Nu = 0.0002800 ---
# Iteration: 0 | Max Psi: 1.4142
# Iteration: 1000 | Max Psi: 1.2923
# Iteration: 2000 | Max Psi: 1.0535
# Iteration: 3000 | Max Psi: 0.8441
# Iteration: 4000 | Max Psi: 0.7312
#
# --- DIFFUSION CONSTANT FINAL PREDICTION RESULTS (MINIMAL 5D) ---
# Fixed Coupling Constant (K_c): 0.00730 (Alpha)
# ---------------------------------------
# Nu = 0.0002300: UNBOUND / DECAYED (Final Mean Mag: 1.6564)
# Nu = 0.0002356: UNBOUND / DECAYED (Final Mean Mag: 1.7461)
# Nu = 0.0002411: UNBOUND / DECAYED (Final Mean Mag: 0.4615)
# Nu = 0.0002467: UNBOUND / DECAYED (Final Mean Mag: 1.9562)
# Nu = 0.0002522: UNBOUND / DECAYED (Final Mean Mag: 1.5597)
# Nu = 0.0002578: UNBOUND / DECAYED (Final Mean Mag: 1.1949)
# Nu = 0.0002633: UNBOUND / DECAYED (Final Mean Mag: 1.4869)
# Nu = 0.0002689: STABLE (Persistent) (Final Mean Mag: 1.9971)
# Nu = 0.0002744: UNBOUND / DECAYED (Final Mean Mag: 1.6604)
# Nu = 0.0002800: UNBOUND / DECAYED (Final Mean Mag: 0.5114)
#
# [Claude-Prime: FINAL PREDICTION] The absolute maximum Emergent Diffusion Constant (Nu_emergent) is: 0.0002689
# [Claude-Prime: Critical Boundary] The critical stability boundary lies between 0.0002689 and 0.0002744.
#
# ---------------------------------------
# This final sweep will solidify the HES model's core set of predicted constants.
